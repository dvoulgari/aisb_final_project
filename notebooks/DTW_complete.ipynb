# %%
# Load necessary libraries
import os
import numpy as np
import pandas as pd
import multiprocessing
from tqdm import tqdm
import warnings
from scipy.spatial.transform import Rotation as R
from Bio.PDB import PDBParser
from Bio import PDB

warnings.filterwarnings("ignore")

# %%
# --- PDB Extraction Function ---
def extract_ca_coordinates(pdb_file):
    """
    Loads a PDB file and extracts C-alpha coordinates for each standard amino acid,
    returning them as a list of NumPy arrays, where each array is (1, 3) for a single residue.
    """
    parser = PDBParser(QUIET=True)
    structure = parser.get_structure("prot", pdb_file)
    
    coords_per_residue = [] 
    
    for model in structure:
        for chain in model:
            for residue in chain:
                if PDB.is_aa(residue, standard=True) and residue.has_id('CA'):
                    coords_per_residue.append(np.array([residue['CA'].coord]))
    
    return coords_per_residue

# %%
# --- calculate_rmsd_after_superposition function ---
def calculate_rmsd_after_superposition(coords1, coords2):
    """
    Calculates the Root Mean Square Deviation (RMSD) between two sets of 3D coordinates
    after optimally superposing coords2 onto coords1 using the Kabsch algorithm (via scipy).

    Args:
        coords1 (np.ndarray): N x 3 array of 3D coordinates (reference).
        coords2 (np.ndarray): M x 3 array of 3D coordinates (to be superposed).

    Returns:
        float: The minimal RMSD between the two sets of coordinates.
    """
    # Robustness checks for empty arrays
    if coords1.shape[0] == 0 and coords2.shape[0] == 0:
        return 0.0 # Both empty, perfectly "aligned" (no cost)
    elif coords1.shape[0] == 0 or coords2.shape[0] == 0:
        # One is empty, the other is not. This should incur a high cost.
        return 1000.0 # A high penalty, indicating a fundamental mismatch
    
    # Handle single-point comparison directly (avoids R.align_vectors issues for N=1)
    if coords1.shape[0] == 1 and coords2.shape[0] == 1:
        return np.linalg.norm(coords1[0] - coords2[0]) # Euclidean distance for 1 point is its RMSD

    # Standard sanity check for 3D coordinates
    if coords1.shape[1] != 3 or coords2.shape[1] != 3:
        raise ValueError("Input coordinate arrays must be (N, 3) or (M, 3).")

    # Center the coordinates
    centroid1 = np.mean(coords1, axis=0)
    centroid2 = np.mean(coords2, axis=0)
    centered_coords1 = coords1 - centroid1
    centered_coords2 = coords2 - centroid2

    # --- Check for degenerate (all points identical / zero length after centering) inputs ---
    # If the sum of squared magnitudes of the centered vectors is effectively zero,
    # it means all points are identical, and alignment is trivial (RMSD is 0).
    is_coords1_degenerate = np.isclose(np.sum(centered_coords1**2), 0.0)
    is_coords2_degenerate = np.isclose(np.sum(centered_coords2**2), 0.0)

    if is_coords1_degenerate and is_coords2_degenerate:
        return 0.0 # Both sets of points are effectively identical (or collapsed to a single point)
    elif is_coords1_degenerate or is_coords2_degenerate:
        # One set is degenerate (e.g., all its atoms are at the same coordinate),
        # while the other is not. This is a significant structural mismatch.
        return 1000.0 # High penalty

    # Find the optimal rotation (will only be called if N > 1 AND not degenerate)
    rotation, rmsd = R.align_vectors(centered_coords2, centered_coords1)

    return rmsd

# %%
# --- dtw_with_rmsd_cost function ---
def dtw_with_rmsd_cost(seq1_coords, seq2_coords):
    """
    Performs Dynamic Time Warping (DTW) on two sequences of 3D backbone coordinates,
    using RMSD as the local cost metric between corresponding residues.

    Args:
        seq1_coords (list of np.ndarray): List where each element is a (1, 3) or (N_atoms, 3)
                                          numpy array representing the coordinates for one residue/segment.
                                          For simple C-alpha, it's (1, 3).
        seq2_coords (list of np.ndarray): Similar list for the second sequence.

    Returns:
        tuple: (dtw_cost, warping_path)
            dtw_cost (float): The total accumulated cost of the optimal warping path.
            warping_path (list): A list of (index_seq1, index_seq2) tuples representing
                                 the optimal alignment path.
    """
    n = len(seq1_coords)
    m = len(seq2_coords)

    # Handle cases where one or both sequences are empty
    if n == 0 and m == 0:
        return 0.0, []
    elif n == 0 or m == 0:
        return np.inf, [] # Infinite cost if one sequence is empty and the other is not

    # Initialize cost matrix
    D = np.full((n + 1, m + 1), np.inf)
    D[0, 0] = 0

    # Fill the cost matrix
    for i in range(1, n + 1):
        for j in range(1, m + 1):
            local_cost = calculate_rmsd_after_superposition(
                seq1_coords[i-1].reshape(-1, 3), # Ensure it's (N_atoms, 3)
                seq2_coords[j-1].reshape(-1, 3)  # Ensure it's (N_atoms, 3)
            )

            # Accumulate cost from previous cells
            D[i, j] = local_cost + min(D[i-1, j],    # Deletion (move right in seq1)
                                      D[i, j-1],    # Insertion (move down in seq2)
                                      D[i-1, j-1])  # Match/Substitution (diagonal)

    # Traceback to find the optimal path
    path = []
    i, j = n, m
    while i > 0 or j > 0:
        path.append((i - 1, j - 1)) # Append 0-indexed values
        if i == 0:
            j -= 1
        elif j == 0:
            i -= 1
        else:
            min_prev = min(D[i-1, j-1], D[i-1, j], D[i, j-1])
            if min_prev == D[i-1, j-1]:
                i -= 1
                j -= 1
            elif min_prev == D[i-1, j]:
                i -= 1
            else: # min_prev == D[i, j-1]:
                j -= 1
    path.reverse() # Path is built backwards, so reverse it

    total_cost = D[n, m]
    length_of_warping_path = len(path)

    if length_of_warping_path > 0:
        normalized_dtw_cost = total_cost / length_of_warping_path
    else:
        # This case should ideally not happen if n > 0 or m > 0 due to path construction,
        # but as a safeguard
        normalized_dtw_cost = np.inf if (n > 0 or m > 0) else 0.0

    return normalized_dtw_cost, path

# %%
# # --- Example Usage ---

# # Load PDB and extract coordinates
# seq1_coords = extract_ca_coordinates('data/1avw.pdb')
# seq2_coords = extract_ca_coordinates('data/1cfd.pdb')

# print(f"Sequence 1 has {len(seq1_coords)} residues.")
# print(f"Sequence 2 has {len(seq2_coords)} residues.")

# if seq1_coords and seq2_coords: # Proceed only if both sequences have data
#     total_cost, path = dtw_with_rmsd_cost(seq1_coords, seq2_coords)

#     print(f"\nTotal DTW Cost: {total_cost:.4f} Angstroms")
#     # --- Code to calculate Normalized DTW Distance ---
#     length_of_warping_path = len(path)
#     if length_of_warping_path > 0:
#         normalized_dtw_distance = total_cost / length_of_warping_path
#         print(f"Normalized DTW Distance (by Warping Length Path): {normalized_dtw_distance:.4f} Angstroms")
#     else:
#         print("Warning: Warping path has zero length, cannot normalize DTW distance.")

#     print("\nOptimal Warping Path:")
#     for i, (idx1, idx2) in enumerate(path):
#         print(f"  Path Step {i+1}: seq1_residue[{idx1}] <-> seq2_residue[{idx2}]")
#     if len(path) > 100:
#         print("  ...")
# else:
#     print("\nError: One or both PDB files resulted in empty C-alpha coordinate lists.")
#     print("Please check the PDB files and the `extract_ca_coordinates` function's filtering conditions.")
# Out:
# Sequence 1 has 394 residues.
# Sequence 2 has 148 residues.
#
# Total DTW Cost: 12004.2280 Angstroms
# Normalized DTW Distance (by Warping Length Path): 30.4676 Angstroms
#
# Optimal Warping Path:
#   Path Step 1: seq1_residue[0] <-> seq2_residue[0]
#   Path Step 2: seq1_residue[1] <-> seq2_residue[1]
#   Path Step 3: seq1_residue[2] <-> seq2_residue[2]
#   Path Step 4: seq1_residue[3] <-> seq2_residue[3]
#   Path Step 5: seq1_residue[4] <-> seq2_residue[4]
#   Path Step 6: seq1_residue[5] <-> seq2_residue[5]
#   Path Step 7: seq1_residue[6] <-> seq2_residue[6]
#   Path Step 8: seq1_residue[7] <-> seq2_residue[7]
#   Path Step 9: seq1_residue[8] <-> seq2_residue[8]
#   Path Step 10: seq1_residue[9] <-> seq2_residue[9]
#   Path Step 11: seq1_residue[10] <-> seq2_residue[10]
#   Path Step 12: seq1_residue[11] <-> seq2_residue[11]
#   Path Step 13: seq1_residue[12] <-> seq2_residue[12]
#   Path Step 14: seq1_residue[13] <-> seq2_residue[13]
#   Path Step 15: seq1_residue[14] <-> seq2_residue[14]
#   Path Step 16: seq1_residue[15] <-> seq2_residue[15]
#   Path Step 17: seq1_residue[16] <-> seq2_residue[16]
#   Path Step 18: seq1_residue[17] <-> seq2_residue[17]
#   Path Step 19: seq1_residue[18] <-> seq2_residue[18]
#   Path Step 20: seq1_residue[19] <-> seq2_residue[19]
#   Path Step 21: seq1_residue[20] <-> seq2_residue[20]
#   Path Step 22: seq1_residue[21] <-> seq2_residue[21]
#   Path Step 23: seq1_residue[22] <-> seq2_residue[22]
#   Path Step 24: seq1_residue[23] <-> seq2_residue[23]
#   Path Step 25: seq1_residue[24] <-> seq2_residue[24]
#   Path Step 26: seq1_residue[25] <-> seq2_residue[25]
#   Path Step 27: seq1_residue[26] <-> seq2_residue[26]
#   Path Step 28: seq1_residue[27] <-> seq2_residue[27]
#   Path Step 29: seq1_residue[28] <-> seq2_residue[28]
#   Path Step 30: seq1_residue[29] <-> seq2_residue[29]
#   Path Step 31: seq1_residue[30] <-> seq2_residue[30]
#   Path Step 32: seq1_residue[31] <-> seq2_residue[31]
#   Path Step 33: seq1_residue[32] <-> seq2_residue[32]
#   Path Step 34: seq1_residue[33] <-> seq2_residue[33]
#   Path Step 35: seq1_residue[34] <-> seq2_residue[34]
#   Path Step 36: seq1_residue[35] <-> seq2_residue[35]
#   Path Step 37: seq1_residue[36] <-> seq2_residue[36]
#   Path Step 38: seq1_residue[37] <-> seq2_residue[37]
#   Path Step 39: seq1_residue[38] <-> seq2_residue[38]
#   Path Step 40: seq1_residue[39] <-> seq2_residue[39]
#   Path Step 41: seq1_residue[40] <-> seq2_residue[39]
#   Path Step 42: seq1_residue[41] <-> seq2_residue[39]
#   Path Step 43: seq1_residue[42] <-> seq2_residue[39]
#   Path Step 44: seq1_residue[43] <-> seq2_residue[39]
#   Path Step 45: seq1_residue[44] <-> seq2_residue[39]
#   Path Step 46: seq1_residue[45] <-> seq2_residue[39]
#   Path Step 47: seq1_residue[46] <-> seq2_residue[39]
#   Path Step 48: seq1_residue[47] <-> seq2_residue[39]
#   Path Step 49: seq1_residue[48] <-> seq2_residue[39]
#   Path Step 50: seq1_residue[49] <-> seq2_residue[39]
#   Path Step 51: seq1_residue[50] <-> seq2_residue[39]
#   Path Step 52: seq1_residue[51] <-> seq2_residue[39]
#   Path Step 53: seq1_residue[52] <-> seq2_residue[39]
#   Path Step 54: seq1_residue[53] <-> seq2_residue[39]
#   Path Step 55: seq1_residue[54] <-> seq2_residue[39]
#   Path Step 56: seq1_residue[55] <-> seq2_residue[39]
#   Path Step 57: seq1_residue[56] <-> seq2_residue[39]
#   Path Step 58: seq1_residue[57] <-> seq2_residue[39]
#   Path Step 59: seq1_residue[58] <-> seq2_residue[39]
#   Path Step 60: seq1_residue[59] <-> seq2_residue[39]
#   Path Step 61: seq1_residue[60] <-> seq2_residue[39]
#   Path Step 62: seq1_residue[61] <-> seq2_residue[39]
#   Path Step 63: seq1_residue[62] <-> seq2_residue[39]
#   Path Step 64: seq1_residue[63] <-> seq2_residue[39]
#   Path Step 65: seq1_residue[64] <-> seq2_residue[39]
#   Path Step 66: seq1_residue[65] <-> seq2_residue[39]
#   Path Step 67: seq1_residue[66] <-> seq2_residue[39]
#   Path Step 68: seq1_residue[67] <-> seq2_residue[39]
#   Path Step 69: seq1_residue[68] <-> seq2_residue[39]
#   Path Step 70: seq1_residue[69] <-> seq2_residue[39]
#   Path Step 71: seq1_residue[70] <-> seq2_residue[39]
#   Path Step 72: seq1_residue[71] <-> seq2_residue[39]
#   Path Step 73: seq1_residue[72] <-> seq2_residue[39]
#   Path Step 74: seq1_residue[73] <-> seq2_residue[39]
#   Path Step 75: seq1_residue[74] <-> seq2_residue[39]
#   Path Step 76: seq1_residue[75] <-> seq2_residue[39]
#   Path Step 77: seq1_residue[76] <-> seq2_residue[39]
#   Path Step 78: seq1_residue[77] <-> seq2_residue[39]
#   Path Step 79: seq1_residue[78] <-> seq2_residue[39]
#   Path Step 80: seq1_residue[79] <-> seq2_residue[39]
#   Path Step 81: seq1_residue[80] <-> seq2_residue[39]
#   Path Step 82: seq1_residue[81] <-> seq2_residue[39]
#   Path Step 83: seq1_residue[82] <-> seq2_residue[39]
#   Path Step 84: seq1_residue[83] <-> seq2_residue[39]
#   Path Step 85: seq1_residue[84] <-> seq2_residue[39]
#   Path Step 86: seq1_residue[85] <-> seq2_residue[39]
#   Path Step 87: seq1_residue[86] <-> seq2_residue[39]
#   Path Step 88: seq1_residue[87] <-> seq2_residue[39]
#   Path Step 89: seq1_residue[88] <-> seq2_residue[39]
#   Path Step 90: seq1_residue[89] <-> seq2_residue[39]
#   Path Step 91: seq1_residue[90] <-> seq2_residue[39]
#   Path Step 92: seq1_residue[91] <-> seq2_residue[39]
#   Path Step 93: seq1_residue[92] <-> seq2_residue[39]
#   Path Step 94: seq1_residue[93] <-> seq2_residue[39]
#   Path Step 95: seq1_residue[94] <-> seq2_residue[39]
#   Path Step 96: seq1_residue[95] <-> seq2_residue[39]
#   Path Step 97: seq1_residue[96] <-> seq2_residue[39]
#   Path Step 98: seq1_residue[97] <-> seq2_residue[39]
#   Path Step 99: seq1_residue[98] <-> seq2_residue[39]
#   Path Step 100: seq1_residue[99] <-> seq2_residue[39]
#   Path Step 101: seq1_residue[100] <-> seq2_residue[39]
#   Path Step 102: seq1_residue[101] <-> seq2_residue[39]
#   Path Step 103: seq1_residue[102] <-> seq2_residue[39]
#   Path Step 104: seq1_residue[103] <-> seq2_residue[39]
#   Path Step 105: seq1_residue[104] <-> seq2_residue[39]
#   Path Step 106: seq1_residue[105] <-> seq2_residue[39]
#   Path Step 107: seq1_residue[106] <-> seq2_residue[39]
#   Path Step 108: seq1_residue[107] <-> seq2_residue[39]
#   Path Step 109: seq1_residue[108] <-> seq2_residue[39]
#   Path Step 110: seq1_residue[109] <-> seq2_residue[39]
#   Path Step 111: seq1_residue[110] <-> seq2_residue[39]
#   Path Step 112: seq1_residue[111] <-> seq2_residue[39]
#   Path Step 113: seq1_residue[112] <-> seq2_residue[39]
#   Path Step 114: seq1_residue[113] <-> seq2_residue[39]
#   Path Step 115: seq1_residue[114] <-> seq2_residue[39]
#   Path Step 116: seq1_residue[115] <-> seq2_residue[39]
#   Path Step 117: seq1_residue[116] <-> seq2_residue[39]
#   Path Step 118: seq1_residue[117] <-> seq2_residue[39]
#   Path Step 119: seq1_residue[118] <-> seq2_residue[39]
#   Path Step 120: seq1_residue[119] <-> seq2_residue[39]
#   Path Step 121: seq1_residue[120] <-> seq2_residue[39]
#   Path Step 122: seq1_residue[121] <-> seq2_residue[39]
#   Path Step 123: seq1_residue[122] <-> seq2_residue[39]
#   Path Step 124: seq1_residue[123] <-> seq2_residue[39]
#   Path Step 125: seq1_residue[124] <-> seq2_residue[39]
#   Path Step 126: seq1_residue[125] <-> seq2_residue[39]
#   Path Step 127: seq1_residue[126] <-> seq2_residue[39]
#   Path Step 128: seq1_residue[127] <-> seq2_residue[39]
#   Path Step 129: seq1_residue[128] <-> seq2_residue[39]
#   Path Step 130: seq1_residue[129] <-> seq2_residue[39]
#   Path Step 131: seq1_residue[130] <-> seq2_residue[39]
#   Path Step 132: seq1_residue[131] <-> seq2_residue[39]
#   Path Step 133: seq1_residue[132] <-> seq2_residue[39]
#   Path Step 134: seq1_residue[133] <-> seq2_residue[39]
#   Path Step 135: seq1_residue[134] <-> seq2_residue[39]
#   Path Step 136: seq1_residue[135] <-> seq2_residue[39]
#   Path Step 137: seq1_residue[136] <-> seq2_residue[39]
#   Path Step 138: seq1_residue[137] <-> seq2_residue[39]
#   Path Step 139: seq1_residue[138] <-> seq2_residue[39]
#   Path Step 140: seq1_residue[139] <-> seq2_residue[39]
#   Path Step 141: seq1_residue[140] <-> seq2_residue[39]
#   Path Step 142: seq1_residue[141] <-> seq2_residue[39]
#   Path Step 143: seq1_residue[142] <-> seq2_residue[39]
#   Path Step 144: seq1_residue[143] <-> seq2_residue[39]
#   Path Step 145: seq1_residue[144] <-> seq2_residue[39]
#   Path Step 146: seq1_residue[145] <-> seq2_residue[39]
#   Path Step 147: seq1_residue[146] <-> seq2_residue[39]
#   Path Step 148: seq1_residue[147] <-> seq2_residue[39]
#   Path Step 149: seq1_residue[148] <-> seq2_residue[39]
#   Path Step 150: seq1_residue[149] <-> seq2_residue[39]
#   Path Step 151: seq1_residue[150] <-> seq2_residue[39]
#   Path Step 152: seq1_residue[151] <-> seq2_residue[39]
#   Path Step 153: seq1_residue[152] <-> seq2_residue[39]
#   Path Step 154: seq1_residue[153] <-> seq2_residue[39]
#   Path Step 155: seq1_residue[154] <-> seq2_residue[39]
#   Path Step 156: seq1_residue[155] <-> seq2_residue[39]
#   Path Step 157: seq1_residue[156] <-> seq2_residue[39]
#   Path Step 158: seq1_residue[157] <-> seq2_residue[39]
#   Path Step 159: seq1_residue[158] <-> seq2_residue[39]
#   Path Step 160: seq1_residue[159] <-> seq2_residue[39]
#   Path Step 161: seq1_residue[160] <-> seq2_residue[39]
#   Path Step 162: seq1_residue[161] <-> seq2_residue[39]
#   Path Step 163: seq1_residue[162] <-> seq2_residue[39]
#   Path Step 164: seq1_residue[163] <-> seq2_residue[39]
#   Path Step 165: seq1_residue[164] <-> seq2_residue[39]
#   Path Step 166: seq1_residue[165] <-> seq2_residue[39]
#   Path Step 167: seq1_residue[166] <-> seq2_residue[39]
#   Path Step 168: seq1_residue[167] <-> seq2_residue[39]
#   Path Step 169: seq1_residue[168] <-> seq2_residue[39]
#   Path Step 170: seq1_residue[169] <-> seq2_residue[39]
#   Path Step 171: seq1_residue[170] <-> seq2_residue[39]
#   Path Step 172: seq1_residue[171] <-> seq2_residue[39]
#   Path Step 173: seq1_residue[172] <-> seq2_residue[39]
#   Path Step 174: seq1_residue[173] <-> seq2_residue[39]
#   Path Step 175: seq1_residue[174] <-> seq2_residue[39]
#   Path Step 176: seq1_residue[175] <-> seq2_residue[39]
#   Path Step 177: seq1_residue[176] <-> seq2_residue[39]
#   Path Step 178: seq1_residue[177] <-> seq2_residue[39]
#   Path Step 179: seq1_residue[178] <-> seq2_residue[39]
#   Path Step 180: seq1_residue[179] <-> seq2_residue[39]
#   Path Step 181: seq1_residue[180] <-> seq2_residue[39]
#   Path Step 182: seq1_residue[181] <-> seq2_residue[39]
#   Path Step 183: seq1_residue[182] <-> seq2_residue[40]
#   Path Step 184: seq1_residue[183] <-> seq2_residue[41]
#   Path Step 185: seq1_residue[184] <-> seq2_residue[41]
#   Path Step 186: seq1_residue[185] <-> seq2_residue[42]
#   Path Step 187: seq1_residue[186] <-> seq2_residue[43]
#   Path Step 188: seq1_residue[187] <-> seq2_residue[44]
#   Path Step 189: seq1_residue[188] <-> seq2_residue[45]
#   Path Step 190: seq1_residue[189] <-> seq2_residue[46]
#   Path Step 191: seq1_residue[190] <-> seq2_residue[47]
#   Path Step 192: seq1_residue[191] <-> seq2_residue[48]
#   Path Step 193: seq1_residue[192] <-> seq2_residue[49]
#   Path Step 194: seq1_residue[193] <-> seq2_residue[50]
#   Path Step 195: seq1_residue[194] <-> seq2_residue[51]
#   Path Step 196: seq1_residue[195] <-> seq2_residue[52]
#   Path Step 197: seq1_residue[196] <-> seq2_residue[53]
#   Path Step 198: seq1_residue[197] <-> seq2_residue[54]
#   Path Step 199: seq1_residue[198] <-> seq2_residue[55]
#   Path Step 200: seq1_residue[199] <-> seq2_residue[56]
#   Path Step 201: seq1_residue[200] <-> seq2_residue[57]
#   Path Step 202: seq1_residue[201] <-> seq2_residue[58]
#   Path Step 203: seq1_residue[202] <-> seq2_residue[59]
#   Path Step 204: seq1_residue[203] <-> seq2_residue[60]
#   Path Step 205: seq1_residue[204] <-> seq2_residue[61]
#   Path Step 206: seq1_residue[205] <-> seq2_residue[62]
#   Path Step 207: seq1_residue[206] <-> seq2_residue[63]
#   Path Step 208: seq1_residue[207] <-> seq2_residue[64]
#   Path Step 209: seq1_residue[208] <-> seq2_residue[65]
#   Path Step 210: seq1_residue[209] <-> seq2_residue[66]
#   Path Step 211: seq1_residue[210] <-> seq2_residue[67]
#   Path Step 212: seq1_residue[211] <-> seq2_residue[68]
#   Path Step 213: seq1_residue[212] <-> seq2_residue[69]
#   Path Step 214: seq1_residue[213] <-> seq2_residue[70]
#   Path Step 215: seq1_residue[214] <-> seq2_residue[71]
#   Path Step 216: seq1_residue[215] <-> seq2_residue[72]
#   Path Step 217: seq1_residue[216] <-> seq2_residue[73]
#   Path Step 218: seq1_residue[217] <-> seq2_residue[74]
#   Path Step 219: seq1_residue[218] <-> seq2_residue[75]
#   Path Step 220: seq1_residue[219] <-> seq2_residue[76]
#   Path Step 221: seq1_residue[220] <-> seq2_residue[77]
#   Path Step 222: seq1_residue[221] <-> seq2_residue[78]
#   Path Step 223: seq1_residue[222] <-> seq2_residue[79]
#   Path Step 224: seq1_residue[223] <-> seq2_residue[80]
#   Path Step 225: seq1_residue[224] <-> seq2_residue[81]
#   Path Step 226: seq1_residue[225] <-> seq2_residue[82]
#   Path Step 227: seq1_residue[226] <-> seq2_residue[83]
#   Path Step 228: seq1_residue[227] <-> seq2_residue[84]
#   Path Step 229: seq1_residue[228] <-> seq2_residue[85]
#   Path Step 230: seq1_residue[229] <-> seq2_residue[86]
#   Path Step 231: seq1_residue[230] <-> seq2_residue[87]
#   Path Step 232: seq1_residue[231] <-> seq2_residue[88]
#   Path Step 233: seq1_residue[232] <-> seq2_residue[89]
#   Path Step 234: seq1_residue[233] <-> seq2_residue[90]
#   Path Step 235: seq1_residue[234] <-> seq2_residue[91]
#   Path Step 236: seq1_residue[235] <-> seq2_residue[92]
#   Path Step 237: seq1_residue[236] <-> seq2_residue[93]
#   Path Step 238: seq1_residue[237] <-> seq2_residue[94]
#   Path Step 239: seq1_residue[238] <-> seq2_residue[95]
#   Path Step 240: seq1_residue[239] <-> seq2_residue[96]
#   Path Step 241: seq1_residue[240] <-> seq2_residue[97]
#   Path Step 242: seq1_residue[241] <-> seq2_residue[98]
#   Path Step 243: seq1_residue[242] <-> seq2_residue[99]
#   Path Step 244: seq1_residue[243] <-> seq2_residue[100]
#   Path Step 245: seq1_residue[244] <-> seq2_residue[101]
#   Path Step 246: seq1_residue[245] <-> seq2_residue[102]
#   Path Step 247: seq1_residue[246] <-> seq2_residue[103]
#   Path Step 248: seq1_residue[247] <-> seq2_residue[104]
#   Path Step 249: seq1_residue[248] <-> seq2_residue[105]
#   Path Step 250: seq1_residue[249] <-> seq2_residue[106]
#   Path Step 251: seq1_residue[250] <-> seq2_residue[107]
#   Path Step 252: seq1_residue[251] <-> seq2_residue[108]
#   Path Step 253: seq1_residue[252] <-> seq2_residue[109]
#   Path Step 254: seq1_residue[253] <-> seq2_residue[109]
#   Path Step 255: seq1_residue[254] <-> seq2_residue[109]
#   Path Step 256: seq1_residue[255] <-> seq2_residue[109]
#   Path Step 257: seq1_residue[256] <-> seq2_residue[109]
#   Path Step 258: seq1_residue[257] <-> seq2_residue[109]
#   Path Step 259: seq1_residue[258] <-> seq2_residue[109]
#   Path Step 260: seq1_residue[259] <-> seq2_residue[109]
#   Path Step 261: seq1_residue[260] <-> seq2_residue[109]
#   Path Step 262: seq1_residue[261] <-> seq2_residue[109]
#   Path Step 263: seq1_residue[262] <-> seq2_residue[109]
#   Path Step 264: seq1_residue[263] <-> seq2_residue[109]
#   Path Step 265: seq1_residue[264] <-> seq2_residue[109]
#   Path Step 266: seq1_residue[265] <-> seq2_residue[109]
#   Path Step 267: seq1_residue[266] <-> seq2_residue[109]
#   Path Step 268: seq1_residue[267] <-> seq2_residue[109]
#   Path Step 269: seq1_residue[268] <-> seq2_residue[109]
#   Path Step 270: seq1_residue[269] <-> seq2_residue[109]
#   Path Step 271: seq1_residue[270] <-> seq2_residue[109]
#   Path Step 272: seq1_residue[271] <-> seq2_residue[109]
#   Path Step 273: seq1_residue[272] <-> seq2_residue[109]
#   Path Step 274: seq1_residue[273] <-> seq2_residue[109]
#   Path Step 275: seq1_residue[274] <-> seq2_residue[109]
#   Path Step 276: seq1_residue[275] <-> seq2_residue[109]
#   Path Step 277: seq1_residue[276] <-> seq2_residue[109]
#   Path Step 278: seq1_residue[277] <-> seq2_residue[110]
#   Path Step 279: seq1_residue[278] <-> seq2_residue[110]
#   Path Step 280: seq1_residue[279] <-> seq2_residue[110]
#   Path Step 281: seq1_residue[280] <-> seq2_residue[111]
#   Path Step 282: seq1_residue[281] <-> seq2_residue[112]
#   Path Step 283: seq1_residue[282] <-> seq2_residue[112]
#   Path Step 284: seq1_residue[283] <-> seq2_residue[112]
#   Path Step 285: seq1_residue[284] <-> seq2_residue[112]
#   Path Step 286: seq1_residue[285] <-> seq2_residue[112]
#   Path Step 287: seq1_residue[286] <-> seq2_residue[112]
#   Path Step 288: seq1_residue[287] <-> seq2_residue[112]
#   Path Step 289: seq1_residue[288] <-> seq2_residue[112]
#   Path Step 290: seq1_residue[289] <-> seq2_residue[112]
#   Path Step 291: seq1_residue[290] <-> seq2_residue[112]
#   Path Step 292: seq1_residue[291] <-> seq2_residue[112]
#   Path Step 293: seq1_residue[292] <-> seq2_residue[112]
#   Path Step 294: seq1_residue[293] <-> seq2_residue[112]
#   Path Step 295: seq1_residue[294] <-> seq2_residue[112]
#   Path Step 296: seq1_residue[295] <-> seq2_residue[112]
#   Path Step 297: seq1_residue[296] <-> seq2_residue[112]
#   Path Step 298: seq1_residue[297] <-> seq2_residue[113]
#   Path Step 299: seq1_residue[298] <-> seq2_residue[114]
#   Path Step 300: seq1_residue[299] <-> seq2_residue[115]
#   Path Step 301: seq1_residue[300] <-> seq2_residue[116]
#   Path Step 302: seq1_residue[301] <-> seq2_residue[116]
#   Path Step 303: seq1_residue[302] <-> seq2_residue[116]
#   Path Step 304: seq1_residue[303] <-> seq2_residue[116]
#   Path Step 305: seq1_residue[304] <-> seq2_residue[116]
#   Path Step 306: seq1_residue[305] <-> seq2_residue[116]
#   Path Step 307: seq1_residue[306] <-> seq2_residue[116]
#   Path Step 308: seq1_residue[307] <-> seq2_residue[116]
#   Path Step 309: seq1_residue[308] <-> seq2_residue[116]
#   Path Step 310: seq1_residue[309] <-> seq2_residue[116]
#   Path Step 311: seq1_residue[310] <-> seq2_residue[116]
#   Path Step 312: seq1_residue[311] <-> seq2_residue[116]
#   Path Step 313: seq1_residue[312] <-> seq2_residue[116]
#   Path Step 314: seq1_residue[313] <-> seq2_residue[116]
#   Path Step 315: seq1_residue[314] <-> seq2_residue[116]
#   Path Step 316: seq1_residue[315] <-> seq2_residue[116]
#   Path Step 317: seq1_residue[316] <-> seq2_residue[116]
#   Path Step 318: seq1_residue[317] <-> seq2_residue[116]
#   Path Step 319: seq1_residue[318] <-> seq2_residue[116]
#   Path Step 320: seq1_residue[319] <-> seq2_residue[116]
#   Path Step 321: seq1_residue[320] <-> seq2_residue[116]
#   Path Step 322: seq1_residue[321] <-> seq2_residue[116]
#   Path Step 323: seq1_residue[322] <-> seq2_residue[116]
#   Path Step 324: seq1_residue[323] <-> seq2_residue[116]
#   Path Step 325: seq1_residue[324] <-> seq2_residue[116]
#   Path Step 326: seq1_residue[325] <-> seq2_residue[116]
#   Path Step 327: seq1_residue[326] <-> seq2_residue[116]
#   Path Step 328: seq1_residue[327] <-> seq2_residue[116]
#   Path Step 329: seq1_residue[328] <-> seq2_residue[116]
#   Path Step 330: seq1_residue[329] <-> seq2_residue[116]
#   Path Step 331: seq1_residue[330] <-> seq2_residue[116]
#   Path Step 332: seq1_residue[331] <-> seq2_residue[116]
#   Path Step 333: seq1_residue[332] <-> seq2_residue[116]
#   Path Step 334: seq1_residue[333] <-> seq2_residue[116]
#   Path Step 335: seq1_residue[334] <-> seq2_residue[116]
#   Path Step 336: seq1_residue[335] <-> seq2_residue[116]
#   Path Step 337: seq1_residue[336] <-> seq2_residue[116]
#   Path Step 338: seq1_residue[337] <-> seq2_residue[116]
#   Path Step 339: seq1_residue[338] <-> seq2_residue[116]
#   Path Step 340: seq1_residue[339] <-> seq2_residue[116]
#   Path Step 341: seq1_residue[340] <-> seq2_residue[116]
#   Path Step 342: seq1_residue[341] <-> seq2_residue[116]
#   Path Step 343: seq1_residue[342] <-> seq2_residue[116]
#   Path Step 344: seq1_residue[343] <-> seq2_residue[116]
#   Path Step 345: seq1_residue[344] <-> seq2_residue[116]
#   Path Step 346: seq1_residue[345] <-> seq2_residue[116]
#   Path Step 347: seq1_residue[346] <-> seq2_residue[116]
#   Path Step 348: seq1_residue[347] <-> seq2_residue[116]
#   Path Step 349: seq1_residue[348] <-> seq2_residue[116]
#   Path Step 350: seq1_residue[349] <-> seq2_residue[116]
#   Path Step 351: seq1_residue[350] <-> seq2_residue[116]
#   Path Step 352: seq1_residue[351] <-> seq2_residue[116]
#   Path Step 353: seq1_residue[352] <-> seq2_residue[116]
#   Path Step 354: seq1_residue[353] <-> seq2_residue[116]
#   Path Step 355: seq1_residue[354] <-> seq2_residue[116]
#   Path Step 356: seq1_residue[355] <-> seq2_residue[116]
#   Path Step 357: seq1_residue[356] <-> seq2_residue[116]
#   Path Step 358: seq1_residue[357] <-> seq2_residue[116]
#   Path Step 359: seq1_residue[358] <-> seq2_residue[116]
#   Path Step 360: seq1_residue[359] <-> seq2_residue[116]
#   Path Step 361: seq1_residue[360] <-> seq2_residue[116]
#   Path Step 362: seq1_residue[361] <-> seq2_residue[116]
#   Path Step 363: seq1_residue[362] <-> seq2_residue[116]
#   Path Step 364: seq1_residue[363] <-> seq2_residue[117]
#   Path Step 365: seq1_residue[364] <-> seq2_residue[118]
#   Path Step 366: seq1_residue[365] <-> seq2_residue[119]
#   Path Step 367: seq1_residue[366] <-> seq2_residue[120]
#   Path Step 368: seq1_residue[367] <-> seq2_residue[121]
#   Path Step 369: seq1_residue[368] <-> seq2_residue[122]
#   Path Step 370: seq1_residue[369] <-> seq2_residue[123]
#   Path Step 371: seq1_residue[370] <-> seq2_residue[124]
#   Path Step 372: seq1_residue[371] <-> seq2_residue[125]
#   Path Step 373: seq1_residue[372] <-> seq2_residue[126]
#   Path Step 374: seq1_residue[373] <-> seq2_residue[127]
#   Path Step 375: seq1_residue[374] <-> seq2_residue[128]
#   Path Step 376: seq1_residue[375] <-> seq2_residue[129]
#   Path Step 377: seq1_residue[376] <-> seq2_residue[130]
#   Path Step 378: seq1_residue[377] <-> seq2_residue[131]
#   Path Step 379: seq1_residue[378] <-> seq2_residue[132]
#   Path Step 380: seq1_residue[379] <-> seq2_residue[133]
#   Path Step 381: seq1_residue[380] <-> seq2_residue[134]
#   Path Step 382: seq1_residue[381] <-> seq2_residue[135]
#   Path Step 383: seq1_residue[382] <-> seq2_residue[136]
#   Path Step 384: seq1_residue[383] <-> seq2_residue[137]
#   Path Step 385: seq1_residue[384] <-> seq2_residue[138]
#   Path Step 386: seq1_residue[385] <-> seq2_residue[139]
#   Path Step 387: seq1_residue[386] <-> seq2_residue[140]
#   Path Step 388: seq1_residue[387] <-> seq2_residue[141]
#   Path Step 389: seq1_residue[388] <-> seq2_residue[142]
#   Path Step 390: seq1_residue[389] <-> seq2_residue[143]
#   Path Step 391: seq1_residue[390] <-> seq2_residue[144]
#   Path Step 392: seq1_residue[391] <-> seq2_residue[145]
#   Path Step 393: seq1_residue[392] <-> seq2_residue[146]
#   Path Step 394: seq1_residue[393] <-> seq2_residue[147]
#   ...

# %% [markdown]
# ---
# ---

# %%
# --- Worker function for parallel processing ---
# This function must be defined at the top level (not inside if __name__ == "__main__":) so it can be pickled and sent to other processes.
def _compare_pair(args):
    pdb_id1, pdb_id2, coords1, coords2 = args
    try:
        dtw_distance, _ = dtw_with_rmsd_cost(coords1, coords2)
        return {'PDB1': pdb_id1, 'PDB2': pdb_id2, 'DTW_Distance_Normalized': dtw_distance}
    except Exception as e:
        # Handle potential errors during comparison, return NaN or a high penalty
        print(f"Error comparing {pdb_id1} and {pdb_id2}: {e}")
        return {'PDB1': pdb_id1, 'PDB2': pdb_id2, 'DTW_Distance_Normalized': np.nan}

# %%
# --- Main Automation Block ---
if __name__ == "__main__":
    pdb_folder_path = "/Users/dvoulgari/Desktop/Structural Bioinfromatics/AISB_Final_Project/20250614_0356239"

    if not os.path.exists(pdb_folder_path):
        print(f"Error: PDB folder not found at '{pdb_folder_path}'. Please check the path.")
        exit()

    # Get list of all PDB files
    pdb_files = [f for f in os.listdir(pdb_folder_path) if f.endswith('.pdb')]
    pdb_files.sort() # Ensure consistent order

    print(f"Found {len(pdb_files)} PDB files in '{pdb_folder_path}'.")
    if len(pdb_files) < 2:
        print("Need at least two PDB files for comparison. Exiting.")
        exit()

    # Cache extracted coordinates to avoid re-parsing PDBs for each comparison
    # This step will still run sequentially first.
    parsed_pdb_coords = {}
    print("Step 1/2: Extracting C-alpha coordinates from all PDB files (sequential)...")
    for pdb_file_name in tqdm(pdb_files, desc="Extracting Coordinates"):
        pdb_full_path = os.path.join(pdb_folder_path, pdb_file_name)
        pdb_id = os.path.splitext(pdb_file_name)[0]
        coords = extract_ca_coordinates(pdb_full_path)
        if len(coords) > 0:
            parsed_pdb_coords[pdb_id] = coords
        else:
            print(f"Skipping {pdb_id} due to empty or problematic C-alpha extraction.")

    valid_pdb_ids = list(parsed_pdb_coords.keys())
    print(f"Successfully extracted C-alpha coordinates for {len(valid_pdb_ids)} valid PDBs.")

    # Prepare tasks for the multiprocessing pool
    tasks = []
    for i in range(len(valid_pdb_ids)):
        pdb_id1 = valid_pdb_ids[i]
        coords1 = parsed_pdb_coords[pdb_id1]
        for j in range(i + 1, len(valid_pdb_ids)): # Compare each unique pair
            pdb_id2 = valid_pdb_ids[j]
            coords2 = parsed_pdb_coords[pdb_id2]
            tasks.append((pdb_id1, pdb_id2, coords1, coords2)) # Store arguments as a tuple

    total_comparisons = len(tasks)
    print(f"Step 2/2: Starting pairwise DTW comparisons ({total_comparisons} in total) using multiprocessing...")

    # Determine the number of CPU cores to use
    num_processes = os.cpu_count()
    if num_processes is None: # Fallback for systems that don't report CPU count
        num_processes = 4 # Default to 4 if not detected
    print(f"Using {num_processes} CPU cores for parallel processing.")

    comparison_results = []
    # Use multiprocessing Pool to distribute tasks
    with multiprocessing.Pool(processes=num_processes) as pool:
        # imap_unordered is good for progress bars as it yields results as they complete
        for result in tqdm(pool.imap_unordered(_compare_pair, tasks), total=total_comparisons, desc="DTW Comparisons"):
            if result is not None: # Collect results, skipping any None from errors
                comparison_results.append(result)

    # Store results in a Pandas DataFrame
    dtw_df = pd.DataFrame(comparison_results)

    # Save to CSV
    output_csv_path = "pairwise_dtw_distances_parallel.csv"
    dtw_df.to_csv(output_csv_path, index=False)
    print(f"\nAll pairwise DTW distances saved to '{output_csv_path}'")

    # Display a sample of the results
    print("\nSample of Pairwise DTW Distances:")
    print(dtw_df.head())

    # Create and save the square distance matrix
    pdb_ids_list = sorted(list(parsed_pdb_coords.keys())) # Ensure consistent order
    distance_matrix = np.full((len(pdb_ids_list), len(pdb_ids_list)), np.nan) # Use nan for self-comparison/uncomputed

    # Create mapping from PDB ID to index
    pdb_id_to_idx = {pdb_id: i for i, pdb_id in enumerate(pdb_ids_list)}

    # Fill diagonal with 0.0 (distance to self)
    np.fill_diagonal(distance_matrix, 0.0)

    for _, row in dtw_df.iterrows():
        idx1 = pdb_id_to_idx[row['PDB1']]
        idx2 = pdb_id_to_idx[row['PDB2']]
        distance_matrix[idx1, idx2] = row['DTW_Distance_Normalized']
        distance_matrix[idx2, idx1] = row['DTW_Distance_Normalized'] # Symmetric matrix

    # Save the distance matrix
    np.save("dtw_distance_matrix_parallel.npy", distance_matrix)
    print(f"DTW distance matrix (NumPy array) saved to 'dtw_distance_matrix_parallel.npy'")
    
    # # Save as CSV for easier viewing (optional, can be very large)
    # distance_matrix_df = pd.DataFrame(distance_matrix, index=pdb_ids_list, columns=pdb_ids_list)
    # distance_matrix_df.to_csv("dtw_distance_matrix_parallel.csv")
    # print(f"DTW distance matrix (CSV) saved to 'dtw_distance_matrix_parallel.csv'")

    print("\nParallel processing complete!")

# %% [markdown]
# The time it takes will depend on a few key factors:
#
# - Average Length of Your Antibody Fv Domains: Your Fv sequences (combined VH and VL) will likely range from 200-300 residues. The core DTW algorithm has a time complexity of roughly O(L1×L2), where L1 and L2are the lengths of the two sequences being compared.
#
# - Efficiency of the Local Cost Calculation (calculate_rmsd_after_superposition): Your implementation of calculate_rmsd_after_superposition for single C-alpha atoms effectively boils down to a fast Euclidean distance calculation (due to the if coords1.shape[0] == 1 check), which is very efficient.

# %%
import numpy as np
from scipy.spatial.transform import Rotation as R

def calculate_global_rmsd(coords1, coords2):
    """
    Calculates the Global Root Mean Square Deviation (RMSD) between two sets of 3D coordinates
    after finding the optimal rigid body superposition using the Kabsch algorithm.

    This function treats the entire set of coordinates as a single rigid body and finds
    the best superposition to minimize the overall distance between corresponding points.
    It's different from local RMSD calculations which might compare smaller segments or
    allow for sequence warping.

    Args:
        coords1 (list of np.ndarray): A list of 3D coordinates for the first structure,
                                       where each element is a (1, 3) numpy array
                                       (e.g., C-alpha coordinates of residues).
        coords2 (list of np.ndarray): A list of 3D coordinates for the second structure,
                                       formatted similarly to coords1.

    Returns:
        float: The global RMSD between the two superposed coordinate sets.
               Returns 0.0 if both inputs are empty.
               Returns a very high value (e.g., 1000.0) if one input is empty,
               indicating a non-comparable state.
    """
    # Convert lists of (1, 3) arrays into single (N, 3) arrays
    # np.vstack stacks the (1, 3) arrays into an (N, 3) array
    np_coords1 = np.vstack(coords1) if coords1 else np.array([])
    np_coords2 = np.vstack(coords2) if coords2 else np.array([])

    n1 = np_coords1.shape[0]
    n2 = np_coords2.shape[0]

    # Handle empty input cases
    if n1 == 0 and n2 == 0:
        return 0.0  # Both empty, RMSD is 0
    if n1 == 0 or n2 == 0:
        return 1000.0  # One empty, cannot compare meaningfully, return a high penalty

    # Ensure the number of points is the same for global RMSD.
    # If not, it means the comparison is inherently different and might need
    # a different metric (like DTW). For a *strict* global RMSD, lengths must match.
    # In this context, we assume they should be compared globally, so if lengths differ,
    # it's a non-sensical global RMSD.
    if n1 != n2:
        print(f"Warning: Global RMSD expects same number of points. Found {n1} and {n2}.")
        # You might choose to raise an error, return NaN, or use a high penalty.
        # Returning a high penalty aligns with how calculate_rmsd_after_superposition
        # handles some edge cases, making it consistent for "non-comparable" states.
        return 1000.0


    # Perform optimal superposition using the Kabsch algorithm
    # R.align_vectors returns a Rotation object and the RMSD
    try:
        _, global_rmsd = R.align_vectors(np_coords1, np_coords2)
        return global_rmsd
    except ValueError as e:
        # Catch potential errors from R.align_vectors (e.g., singular matrix if all points are identical)
        print(f"Error during global RMSD calculation: {e}")
        # If alignment fails, it indicates a problematic comparison, return a high penalty
        return 1000.0
